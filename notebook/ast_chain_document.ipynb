# %% [markdown]
# ## STEP 1 — Load ast_index.jsonl di LangChain

# %%
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path="../data/ast_data/ast_index.jsonl",
    jq_schema=".",
    content_key="content",
    metadata_func=lambda record, metadata: record["metadata"],
    json_lines=True
)

docs = loader.load()
docs
# print(docs[0].page_content)
# print(docs[0].metadata)
# print(docs[0])
# Out:
# [Document(metadata={'Name': 'IOrderService', 'Namespace': 'Application', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'InterfaceDeclaration'}, page_content='Class: IOrderService\r\nNamespace: Application\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask CreateOrderApprovalAsync()'),
#  Document(metadata={'Name': 'OrderService', 'Namespace': 'Application', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: OrderService\r\nNamespace: Application\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\n'),
#  Document(metadata={'Name': 'WeatherForecast', 'Namespace': 'OrderService', 'Layer': 'Presentation', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: WeatherForecast\r\nNamespace: OrderService\r\nLayer: Presentation\r\nAggregateRoot: False\r\n\r\nProperties:\r\nDateOnly Date\nint TemperatureC\nint TemperatureF\nstring? Summary\r\n\r\nMethods:\r\n'),
#  Document(metadata={'Name': 'GetOrderQuery', 'Namespace': 'Application.Orders.Queries', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'RecordDeclaration'}, page_content='Class: GetOrderQuery\r\nNamespace: Application.Orders.Queries\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\n'),
#  Document(metadata={'Name': 'BaseEntity', 'Namespace': 'Domain.Common', 'Layer': 'Domain', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: BaseEntity\r\nNamespace: Domain.Common\r\nLayer: Domain\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\n'),
#  Document(metadata={'Name': 'Order', 'Namespace': 'Domain.Entities', 'Layer': 'Domain', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: Order\r\nNamespace: Domain.Entities\r\nLayer: Domain\r\nAggregateRoot: False\r\n\r\nProperties:\r\nGuid Id\nstring CustomerName\nIReadOnlyCollection<OrderItem> Items\nDateTime CreatedAt\r\n\r\nMethods:\r\nvoid AddItem()\ndecimal Total()'),
#  Document(metadata={'Name': 'IOrderRepository', 'Namespace': 'Domain.Interfaces', 'Layer': 'Domain', 'IsAggregateRoot': False, 'Type': 'InterfaceDeclaration'}, page_content='Class: IOrderRepository\r\nNamespace: Domain.Interfaces\r\nLayer: Domain\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask<Order?> GetByIdAsync()\nTask AddAsync()\nTask SaveChangesAsync()'),
#  Document(metadata={'Name': 'Initial', 'Namespace': 'Infrastructure.Migrations', 'Layer': 'Infrastructure', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: Initial\r\nNamespace: Infrastructure.Migrations\r\nLayer: Infrastructure\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nvoid Up()\nvoid Down()'),
#  Document(metadata={'Name': 'Initial', 'Namespace': 'Infrastructure.Migrations', 'Layer': 'Infrastructure', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: Initial\r\nNamespace: Infrastructure.Migrations\r\nLayer: Infrastructure\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nvoid BuildTargetModel()'),
#  Document(metadata={'Name': 'AppDbContextModelSnapshot', 'Namespace': 'Infrastructure.Migrations', 'Layer': 'Infrastructure', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: AppDbContextModelSnapshot\r\nNamespace: Infrastructure.Migrations\r\nLayer: Infrastructure\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nvoid BuildModel()'),
#  Document(metadata={'Name': 'AppDbContext', 'Namespace': 'Infrastructure.Persistence', 'Layer': 'Infrastructure', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: AppDbContext\r\nNamespace: Infrastructure.Persistence\r\nLayer: Infrastructure\r\nAggregateRoot: False\r\n\r\nProperties:\r\nDbSet<Order> Orders\r\n\r\nMethods:\r\nvoid OnModelCreating()'),
#  Document(metadata={'Name': 'OrderRepository', 'Namespace': 'Infrastructure.Repositories', 'Layer': 'Infrastructure', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: OrderRepository\r\nNamespace: Infrastructure.Repositories\r\nLayer: Infrastructure\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask AddAsync()\nTask<Order?> GetByIdAsync()\nTask SaveChangesAsync()'),
#  Document(metadata={'Name': 'OrdersController', 'Namespace': 'Global', 'Layer': 'Presentation', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: OrdersController\r\nNamespace: Global\r\nLayer: Presentation\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask<IActionResult> Create()\nTask<IActionResult> Get()'),
#  Document(metadata={'Name': 'WeatherForecastController', 'Namespace': 'OrderService.Controllers', 'Layer': 'Presentation', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: WeatherForecastController\r\nNamespace: OrderService.Controllers\r\nLayer: Presentation\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nIEnumerable<WeatherForecast> Get()'),
#  Document(metadata={'Name': 'CreateOrderCommand', 'Namespace': 'Application.Orders.Commands', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'RecordDeclaration'}, page_content='Class: CreateOrderCommand\r\nNamespace: Application.Orders.Commands\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\n'),
#  Document(metadata={'Name': 'GetOrderHandler', 'Namespace': 'Application.Orders.Queries', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: GetOrderHandler\r\nNamespace: Application.Orders.Queries\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask<OrderDto?> Handle()'),
#  Document(metadata={'Name': 'CreateOrderHandler', 'Namespace': 'Application.Orders.Commands.CreateOrder', 'Layer': 'Application', 'IsAggregateRoot': False, 'Type': 'ClassDeclaration'}, page_content='Class: CreateOrderHandler\r\nNamespace: Application.Orders.Commands.CreateOrder\r\nLayer: Application\r\nAggregateRoot: False\r\n\r\nProperties:\r\n\r\n\r\nMethods:\r\nTask<Guid> Handle()')]

# %% [markdown]
# ## STEP 3 — Embedding ke Chroma (Ollama)

# %%
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings import OllamaEmbeddings

vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=OllamaEmbeddings(model="nomic-embed-text"),
    persist_directory="./chroma_ast"
)

vectorstore.persist()
# Out:
# C:\Users\wibow\AppData\Local\Temp\ipykernel_22352\1185385336.py:10: LangChainDeprecationWarning: Since Chroma 0.4.x the manual persistence method is no longer supported as docs are automatically persisted.
#   vectorstore.persist()

# %% [markdown]
# ## STEP 4 — Query dengan FILTER AST

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={
        "k": 5,
        "filter": {
            "Layer": "Domain",
            "IsAggregateRoot": True
        }
    }
)

context_docs = retriever.invoke("Order AggregateRoot")
print(context_docs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 11
#       1 retriever = vectorstore.as_retriever(
#       2     search_kwargs={
#       3         "k": 5,
#    (...)      8     }
#       9 )
# ---> 11 context_docs = retriever.invoke("Order AggregateRoot")
#      12 print(context_docs)
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_core\retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:1040, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1038 kwargs_ = self.search_kwargs | kwargs
#    1039 if self.search_type == "similarity":
# -> 1040     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1041 elif self.search_type == "similarity_score_threshold":
#    1042     docs_and_similarities = (
#    1043         self.vectorstore.similarity_search_with_relevance_scores(
#    1044             query, **kwargs_
#    1045         )
#    1046     )
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:350, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     333 def similarity_search(
#     334     self,
#     335     query: str,
#    (...)    338     **kwargs: Any,
#     339 ) -> List[Document]:
#     340     """Run similarity search with Chroma.
#     341
#     342     Args:
#    (...)    348         List[Document]: List of documents most similar to the query text.
#     349     """
# --> 350     docs_and_scores = self.similarity_search_with_score(
#     351         query, k, filter=filter, **kwargs
#     352     )
#     353     return [doc for doc, _ in docs_and_scores]
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:440, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     438 else:
#     439     query_embedding = self._embedding_function.embed_query(query)
# --> 440     results = self.__query_collection(
#     441         query_embeddings=[query_embedding],
#     442         n_results=k,
#     443         where=filter,
#     444         where_document=where_document,
#     445         **kwargs,
#     446     )
#     448 return _results_to_docs_and_scores(results)
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_core\utils\utils.py:52, in xor_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      46     msg = (
#      47         "Exactly one argument in each of the following"
#      48         " groups must be defined:"
#      49         f" {', '.join(invalid_group_names)}"
#      50     )
#      51     raise ValueError(msg)
# ---> 52 return func(*args, **kwargs)
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:157, in Chroma.__query_collection(self, query_texts, query_embeddings, n_results, where, where_document, **kwargs)
#     152 except ImportError:
#     153     raise ImportError(
#     154         "Could not import chromadb python package. "
#     155         "Please install it with `pip install chromadb`."
#     156     )
# --> 157 return self._collection.query(
#     158     query_texts=query_texts,
#     159     query_embeddings=query_embeddings,
#     160     n_results=n_results,
#     161     where=where,
#     162     where_document=where_document,
#     163     **kwargs,
#     164 )
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\chromadb\api\models\Collection.py:217, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     172 def query(
#     173     self,
#     174     query_embeddings: Optional[
#    (...)    191     ],
#     192 ) -> QueryResult:
#     193     """Get the n_results nearest neighbor embeddings for provided query_embeddings or query_texts.
#     194
#     195     Args:
#    (...)    214
#     215     """
# --> 217     query_request = self._validate_and_prepare_query_request(
#     218         query_embeddings=query_embeddings,
#     219         query_texts=query_texts,
#     220         query_images=query_images,
#     221         query_uris=query_uris,
#     222         ids=ids,
#     223         n_results=n_results,
#     224         where=where,
#     225         where_document=where_document,
#     226         include=include,
#     227     )
#     229     query_results = self._client._query(
#     230         collection_id=self.id,
#     231         ids=query_request["ids"],
#    (...)    238         database=self.database,
#     239     )
#     241     return self._transform_query_response(
#     242         response=query_results, include=query_request["include"]
#     243     )
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:103, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#     100 @functools.wraps(func)
#     101 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102     try:
# --> 103         return func(self, *args, **kwargs)
#     104     except Exception as e:
#     105         msg = f"{str(e)} in {name}."
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\chromadb\api\models\CollectionCommon.py:329, in CollectionCommon._validate_and_prepare_query_request(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     327 # Validate
#     328 validate_base_record_set(record_set=query_records)
# --> 329 validate_filter_set(filter_set=filters)
#     330 validate_include(include=include)
#     331 validate_n_results(n_results=n_results)
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\chromadb\api\types.py:545, in validate_filter_set(filter_set)
#     543 def validate_filter_set(filter_set: FilterSet) -> None:
#     544     if filter_set["where"] is not None:
# --> 545         validate_where(filter_set["where"])
#     546     if filter_set["where_document"] is not None:
#     547         validate_where_document(filter_set["where_document"])
#
# File c:\Users\wibow\Documents\ytrag\.venv\Lib\site-packages\chromadb\api\types.py:1107, in validate_where(where)
#    1105     raise ValueError(f"Expected where to be a dict, got {where}")
#    1106 if len(where) != 1:
# -> 1107     raise ValueError(f"Expected where to have exactly one operator, got {where}")
#    1108 for key, value in where.items():
#    1109     if not isinstance(key, str):
#
# ValueError: Expected where to have exactly one operator, got {'Layer': 'Domain', 'IsAggregateRoot': True} in query.

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={
        "k": 5,
        "filter": {
            "Layer": "Domain",
            "IsAggregateRoot": True
        }
    }
)
print(retriever)
# Out:
# tags=['Chroma', 'OllamaEmbeddings'] vectorstore=<langchain_community.vectorstores.chroma.Chroma object at 0x0000020D988B9130> search_kwargs={'k': 5, 'filter': {'Layer': 'Domain', 'IsAggregateRoot': True}}

# %% [markdown]
# ## 🤖 STEP 7 — RAG Chain (Ollama Chat)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_community.chat_models import ChatOllama


llm = ChatOllama(
    model="llama3.1",
    temperature=0
)


# prompt = ChatPromptTemplate.from_template("""
# Kamu adalah senior C# architect.
# Ikuti Clean Architecture:
# - Domain tidak bergantung ke layer lain
# - Application berisi Use Case
# - Infrastructure hanya implementasi

# 1. Gunakan pola yang SUDAH ADA di repository.
# 2. Gunakan struktur AST berikut untuk membuat Use Case

# Context:
# {context}

# Question:
# {question}
# """)
prompt =ChatPromptTemplate.from_template("""
Kamu adalah senior C# architect.

Context AST (Domain & Application):
{context}

Buatkan:
1. Command (record)
2. Handler (implements IRequestHandler)
3. Interface Repository (Domain)

Rules:
- Clean Architecture
- Domain tidak bergantung ke Application
- Gunakan pola existing di repo
- Jangan membuat logic di Controller

Question:
{question}
""")

retriever = vectorstore.as_retriever(
    search_kwargs={
        "k": 6,
        "filter": {
            "Layer": {"$in": ["Domain", "Application"]}
        }
    }
)

rag_chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
)

# %%
query_orderApproval = """
Buatkan Use Case untuk Approve Order
berdasarkan pola yang sudah ada di Application layer
dan entity di Domain
"""
result = rag_chain.invoke(
   query_orderApproval
)

print(result.content)
# Out:
# Berikut adalah implementasi yang sesuai dengan aturan-aturan yang telah ditentukan:
#
# **1. Command (record)**
#
# Membuat command `CreateOrderCommand` sebagai record:
# ```csharp
# public class CreateOrderCommand : ICommand
# {
#     public Guid Id { get; }
#     public string CustomerName { get; }
#     public IReadOnlyCollection<OrderItem> Items { get; }
#
#     public CreateOrderCommand(Guid id, string customerName, IReadOnlyCollection<OrderItem> items)
#     {
#         Id = id;
#         CustomerName = customerName;
#         Items = items;
#     }
# }
# ```
# **2. Handler (implements IRequestHandler)**
#
# Membuat handler `CreateOrderHandler` yang mengimplementasikan `IRequestHandler<CreateOrderCommand>`:
# ```csharp
# public class CreateOrderHandler : IRequestHandler<CreateOrderCommand>
# {
#     private readonly IOrderRepository _repository;
#
#     public CreateOrderHandler(IOrderRepository repository)
#     {
#         _repository = repository;
#     }
#
#     public async Task HandleAsync(CreateOrderCommand command)
#     {
#         var order = new Order(command.Id, command.CustomerName);
#         foreach (var item in command.Items)
#         {
#             order.AddItem(item);
#         }
#         await _repository.AddAsync(order);
#     }
# }
# ```
# **3. Interface Repository (Domain)**
#
# Membuat interface repository `IOrderRepository` di domain:
# ```csharp
# public interface IOrderRepository : IRepository<Order>
# {
#     Task AddAsync(Order order);
#     Task SaveChangesAsync();
# }
# ```
# Catatan:
#
# * `ICommand` adalah antarmuka yang harus digunakan oleh command.
# * `IRequestHandler<T>` adalah antarmuka yang harus digunakan oleh handler untuk menghandle request.
# * `IRepository<T>` adalah antarmuka yang harus digunakan oleh repository untuk mengelola data.
#
# Dengan implementasi di atas, kita telah memenuhi aturan-aturan yang telah ditentukan:
#
# * Clean Architecture: Domain tidak bergantung ke Application.
# * Domain tidak bergantung ke Application: Handler dan Repository berada di domain, sedangkan Controller berada di aplikasi.
# * Gunakan pola existing di repo: Repository menggunakan pola existing seperti `AddAsync` dan `SaveChangesAsync`.
# * Jangan membuat logic di Controller: Logic untuk menghandle request telah dipindahkan ke handler.
